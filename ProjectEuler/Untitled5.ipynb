# %%
def s(n):
    c = 0
    
    for p_x in range(1,n+1):
        for q_y in range(1,n+1):
            print('p')
            print(p_x,0)
            print('q')
            print(0,q_y)
            print('\n')
            c += 2
                
    for q_y in range(1,n+1):
        c += 2
        
    c += 2
                
    return c

# %%
def s(n):
    c = 0
    
    # if perpendicular
    for

# %%
s(50)
# Out:
# p
# 1 0
# q
# 0 1
#
#
# p
# 1 0
# q
# 0 2
#
#
# p
# 1 0
# q
# 0 3
#
#
# p
# 1 0
# q
# 0 4
#
#
# p
# 1 0
# q
# 0 5
#
#
# p
# 1 0
# q
# 0 6
#
#
# p
# 1 0
# q
# 0 7
#
#
# p
# 1 0
# q
# 0 8
#
#
# p
# 1 0
# q
# 0 9
#
#
# p
# 1 0
# q
# 0 10
#
#
# p
# 1 0
# q
# 0 11
#
#
# p
# 1 0
# q
# 0 12
#
#
# p
# 1 0
# q
# 0 13
#
#
# p
# 1 0
# q
# 0 14
#
#
# p
# 1 0
# q
# 0 15
#
#
# p
# 1 0
# q
# 0 16
#
#
# p
# 1 0
# q
# 0 17
#
#
# p
# 1 0
# q
# 0 18
#
#
# p
# 1 0
# q
# 0 19
#
#
# p
# 1 0
# q
# 0 20
#
#
# p
# 1 0
# q
# 0 21
#
#
# p
# 1 0
# q
# 0 22
#
#
# p
# 1 0
# q
# 0 23
#
#
# p
# 1 0
# q
# 0 24
#
#
# p
# 1 0
# q
# 0 25
#
#
# p
# 1 0
# q
# 0 26
#
#
# p
# 1 0
# q
# 0 27
#
#
# p
# 1 0
# q
# 0 28
#
#
# p
# 1 0
# q
# 0 29
#
#
# p
# 1 0
# q
# 0 30
#
#
# p
# 1 0
# q
# 0 31
#
#
# p
# 1 0
# q
# 0 32
#
#
# p
# 1 0
# q
# 0 33
#
#
# p
# 1 0
# q
# 0 34
#
#
# p
# 1 0
# q
# 0 35
#
#
# p
# 1 0
# q
# 0 36
#
#
# p
# 1 0
# q
# 0 37
#
#
# p
# 1 0
# q
# 0 38
#
#
# p
# 1 0
# q
# 0 39
#
#
# p
# 1 0
# q
# 0 40
#
#
# p
# ...
